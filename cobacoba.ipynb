# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
a = plt.imread('Dataset/DefectFree/0a710af85aca048e0828541034.jpg')
plt.imshow(a)

# %%
a = plt.imread('Dataset/DefectFree/33.jpg')
plt.imshow(a)

# %%
a = plt.imread('Dataset/DefectStain/11.jpg')
plt.imshow(a)

# %%
a_gray = cv2.cvtColor(a, cv2.COLOR_BGR2GRAY)
plt.imshow(a_gray, cmap='gray')
